# %% [markdown]
# # Standard Deviation Plots Measuring the Spread

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Generating a random dataset
data = np.random.normal(50, 15, 100)
data
# Out:
# array([28.21937123, 75.3608307 , 43.99439675, 46.11701442, 23.30957367,
#        54.82617758, 51.99422628, 19.463068  , 72.00387552, 68.86728586,
#        33.66526437, 68.38538782, 23.56358299, 67.06948131, 44.129487  ,
#        40.1502933 , 28.97587961, 59.17305225, 53.63252488, 60.50589384,
#        43.77778306, 45.52235372, 27.9506847 , 67.75895309, 67.97485208,
#        58.58273684, 57.91471058, 50.43985493, 44.37633437, 61.26687985,
#        44.44693688, 70.17818253, 35.9107681 , 54.10532039, 56.59413419,
#        45.43828175, 62.27947621, 60.64287188, 51.00175283, 45.26761117,
#        67.29039455, 35.49308371, 50.66156782, 16.1443301 , 65.63473051,
#        28.26098362, 67.47525674, 51.62503273, 53.63006794, 39.26853055,
#        33.5171715 , 42.95516807, 62.2829907 , 57.21804105, 47.45937883,
#        59.59471865, 55.93990011, 54.78419076, 32.34664371, 50.20824357,
#        50.28198337, 47.87092096, 35.312374  , 46.35928726, 56.00018831,
#        81.4526696 , 71.88546967, 37.67941744,  8.91560185, 52.40665653,
#        57.94568858, 51.61534724, 47.0629305 , 73.67817301, 33.0144087 ,
#        38.26327708, 46.50861168, 38.52046479, 27.76173724, 39.84908892,
#        70.93608411, 33.51370025, 49.71528603, 82.56239963, 47.51305301,
#        53.99060608, 54.93022552, 47.50646865, 45.10629743, 49.51663262,
#        29.4306759 , 56.55961727, 41.77440446, 61.40678374,  8.02517899,
#        48.94671154, 43.2642006 , 36.56319095, 51.90204886, 54.19957716])

# %%
data.shape, data.ndim
# Out:
# ((100,), 1)

# %%
# Plotting Histogram

plt.figure(figsize=(14, 4))
plt.subplot(1, 3, 1)
plt.hist(data, bins=15, color='skyblue', alpha= 0.7)
plt.title('Histogram')
plt.xlabel('Data Points')
plt.ylabel('Frequency');

# %% [markdown]
# # Plotting Box Plot

# %%
plt.subplot(1,3,2)
sns.boxplot(data, orient='h', color='lightgreen')
plt.title('Box Plot')
plt.xlabel('Data Points');

# %% [markdown]
# # Plotting Standard Deviation Plot

# %%
mean = np.mean(data)
std_dev = np.std(data)
plt.subplot(1, 3, 3)
plt.errorbar(mean, 0, xerr=std_dev, fmt='o', color='purple', elinewidth=3, ecolor='purple', capsize=5)
plt.yticks([])
plt.title('Standard deviation plot of data')
plt.xlabel('Data Points')
# Out:
# Text(0.5, 0, 'Data Points')

# %% [markdown]
# # Show all plots

# %%
# Plotting Histogram

plt.figure(figsize=(14, 4))
plt.subplot(1, 3, 1)
plt.hist(data, bins=15, color='skyblue', alpha= 0.7)
plt.title('Histogram')
plt.xlabel('Data Points')
plt.ylabel('Frequency');

plt.subplot(1,3,2)
sns.boxplot(data, orient='h', color='lightgreen')
plt.title('Box Plot')
plt.xlabel('Data Points');

mean = np.mean(data)
std_dev = np.std(data)
plt.subplot(1, 3, 3)
plt.errorbar(mean, 0, xerr=std_dev, fmt='o', color='purple', elinewidth=3, ecolor='purple', capsize=5)
plt.yticks([])
plt.title('Standard deviation plot of data')
plt.xlabel('Data Points')


plt.tight_layout()
plt.show()
